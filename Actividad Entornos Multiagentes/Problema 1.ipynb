# %% [markdown]
# # Problema 1

# %% [markdown]
# Considere un juego de disparejo entre cuatro jugadores, en el que cada jugador adopta la siguiente estrategia:
#
# - El jugador 1 siempre escoge al azar entre las dos opciones.
# - El jugador 2 escoge siempre hacia abajo sin importar lo que haya ocurrido anteriormente.
# - El jugador 3 escoge la última opción ganadora de las partidas anteriores. En la primera jugada, escoge arriba.
# - El jugador 4 escoge aquello opuesto al jugador 1 en la última partida. En la primera jugada, escoge al azar.
#
# Utilice AgentPy para generar una simulación del juego, y simule 1000 juegos consecutivos. Muestre los resultados obtenidos para cada uno de los jugadores al final de la simulación.
#
# ¿Qué jugador obtuvo mejores resultados? ¿Alguna de las estrategias fue mejor que las otras?

# %%
# Model design
import agentpy as ap
import networkx as nx 
import numpy as np 
import random 


# Visualization
import matplotlib.pyplot as plt 
import seaborn as sns
import IPython
from random import randint

# %%
class Player(ap.Agent):

    """ Agente Jugador de disparejo """

    def setup(self):

        self.strategy = 0       # None = 0, Strategy1 = 1, Strategy2 = 2, Strategy3 = 3, Strategy4 = 4
        self.choice = 0         # Down = 0, Up = 1
        self.lastWinner = 2     # FirstRound = 2
        self.lastFirstPlayerChoice = 0
        
    def Strategy1(self):

        self.choice = randint(0, 1)

    def Strategy2(self):

        self.choice = 0
    
    def Strategy3(self):

        if self.lastWinner == 2:
            self.choice = 1
        else:
            self.choice = self.lastWinner
    
    def Strategy4(self):

        if self.lastWinner == 2:
            self.choice = randint(0, 1)
        else:
            if self.lastFirstPlayerChoice == 0:
                self.choice = 1
            else:
                self.choice = 0

# %%
class DisparejoModel(ap.Model):
    
    def setup(self):
        """ Initialize the agents of the model. """
        # Create agents
        self.agents = ap.AgentList(self, self.p.agents, Player)
        arr = [1, 2, 3, 4]
        for i in range(4):
            self.agents[i].strategy = arr[i]

    def step(self):
        empate = 0
        gana1 = 0
        gana0 = 0
        for i in range(4):
            if self.agents[i].strategy == 1:
                self.agents[i].Strategy1()

            if self.agents[i].strategy == 2:
                self.agents[i].Strategy2()

            if self.agents[i].strategy == 3:
                self.agents[i].Strategy3()
                
            if self.agents[i].strategy == 4:
                self.agents[i].Strategy4()
                
        self.agents.lastWinner = 1

        UP_Agents = len(self.agents.select(self.agents.choice == 1))
        DOWN_Agents = len(self.agents.select(self.agents.choice == 0))
        
        if UP_Agents == 1: 
            gana1 = 1
            self.agents.lastWinner = 1    
        else:
            if DOWN_Agents == 1: 
                gana0 = 1
                self.agents.lastWinner = 0  
            else: 
                if UP_Agents == DOWN_Agents or UP_Agents== 4 or DOWN_Agents== 4:
                    empate=1
                    self.agents.lastWinner = 2

        if empate == 1:
            print("Empate ")
            self.record('Partida', str(self.agents.choice))
            self.record('Winner ', 5)
            self.p.empates= self.p.empates+1
        else:
            if gana0 == 1:
                for r in range(4):
                    if str(self.agents.select(self.agents.strategy == r+1).choice) == "[0]":
                        print(r+1)
                        self.record('Partida', str(self.agents.choice))
                        self.record('Winner ', r+1)
                        if r+1 == 1:
                            self.p.wins1= self.p.wins1+1
                        if r+1== 2:
                            self.p.wins2= self.p.wins2+1
                        if r+1 == 3:
                            self.p.wins3= self.p.wins3+1
                        if r+1 == 4:
                            self.p.wins4= self.p.wins4+1
                        
            if gana1== 1:
                for l in range(4):
                    if str(self.agents.select(self.agents.strategy == l+1).choice) == "[1]":
                        print(l+1)
                        self.record('Partida', str(self.agents.choice))
                        self.record('Winner ', l+1)
                        if l+1 == 1:
                            self.p.wins1= self.p.wins1+1
                        if l+1== 2:
                            self.p.wins2= self.p.wins2+1
                        if l+1 == 3:
                            self.p.wins3= self.p.wins3+1
                        if l+1 == 4:
                            self.p.wins4= self.p.wins4+1

        if self.p.empates+self.p.wins1+self.p.wins2+self.p.wins3+self.p.wins4 == self.p.steps:
            print("Victorias jugador 1: " + str(self.p.wins1))
            print("Victorias jugador 2: " + str(self.p.wins2))
            print("Victorias jugador 3: " + str(self.p.wins3))
            print("Victorias jugador 4: " + str(self.p.wins4))
            print("Empates : " + str(self.p.empates))

            if self.p.wins1 > self.p.wins2 and self.p.wins1 > self.p.wins3 and self.p.wins1 > self.p.wins4 :
                print("Ganó jugador 1: " + str(self.p.wins1) + " veces")
                self.report('Jugador ganador: ', 1)
            else :
                if self.p.wins2 > self.p.wins1 and self.p.wins2 > self.p.wins3 and self.p.wins2 > self.p.wins4 :
                    print("Ganó jugador 2: " + str(self.p.wins2) + " veces")
                    self.report('Jugador ganador: ', 2)
                else:
                    if self.p.wins3 > self.p.wins1 and self.p.wins3 > self.p.wins2 and self.p.wins3 > self.p.wins4 :
                        print("Ganó jugador 3: " + str(self.p.wins3) + " veces")
                        self.report('Jugador ganador: ', 3)
                    else: 
                        if self.p.wins4 > self.p.wins1 and self.p.wins4 > self.p.wins2 and self.p.wins4 > self.p.wins3 :
                            print("Ganó jugador 4: " + str(self.p.wins4) + " veces")
                            self.report('Jugador ganador: ', 4)
                        else:
                            print("No hay ganador")
                            self.report('Jugador ganador: ', 0)   
        
        var1 = self.agents.select(self.agents.strategy == 1).choice
        self.agents.select(self.agents.strategy == 1).lastFirstPlayerChoice = var1
        self.agents.select(self.agents.strategy == 2).lastFirstPlayerChoice = var1
        self.agents.select(self.agents.strategy == 3).lastFirstPlayerChoice = var1
        self.agents.select(self.agents.strategy == 4).lastFirstPlayerChoice = var1

# %%
parameters = {
    'agents': 4,
    'steps': 1000,
    'wins1': 0,
    'wins2': 0,
    'wins3': 0,
    'wins4': 0,
    'empates': 0,
}

model = DisparejoModel(parameters)
results = model.run()
# Out:
# Empate
# Completed: 1 stepsEmpate
# Completed: 2 steps3
# Completed: 3 steps2
# Completed: 4 stepsEmpate
# Completed: 5 stepsEmpate
# Completed: 6 steps2
# Completed: 7 stepsEmpate
# Completed: 8 steps2
# Completed: 9 steps1
# Completed: 10 steps3
# Completed: 11 steps2
# Completed: 12 steps1
# Completed: 13 steps3
# Completed: 14 steps2
# Completed: 15 stepsEmpate
# Completed: 16 steps2
# Completed: 17 stepsEmpate
# Completed: 18 stepsEmpate
# Completed: 19 steps2
# Completed: 20 stepsEmpate
# Completed: 21 stepsEmpate
# Completed: 22 stepsEmpate
# Completed: 23 stepsEmpate
# Completed: 24 steps2
# Completed: 25 steps1
# Completed: 26 steps3
# Completed: 27 steps2
# Completed: 28 stepsEmpate
# Completed: 29 stepsEmpate
# Completed: 30 stepsEmpate
# Completed: 31 steps2
# Completed: 32 stepsEmpate
# Completed: 33 stepsEmpate
# Completed: 34 steps3
# Completed: 35 steps2
# Completed: 36 stepsEmpate
# Completed: 37 stepsEmpate
# Completed: 38 steps2
# Completed: 39 stepsEmpate
# Completed: 40 steps3
# Completed: 41 steps2
# Completed: 42 steps1
# Completed: 43 steps3
# Completed: 44 steps2
# Completed: 45 stepsEmpate
# Completed: 46 steps2
# Completed: 47 steps1
# Completed: 48 stepsEmpate
# Completed: 49 stepsEmpate
# Completed: 50 steps2
# Completed: 51 steps1
# Completed: 52 stepsEmpate
# Completed: 53 stepsEmpate
# Completed: 54 stepsEmpate
# Completed: 55 stepsEmpate
# Completed: 56 steps2
# Completed: 57 steps1
# Completed: 58 stepsEmpate
# Completed: 59 stepsEmpate
# Completed: 60 steps2
# Completed: 61 stepsEmpate
# Completed: 62 steps3
# Completed: 63 steps2
# Completed: 64 stepsEmpate
# Completed: 65 steps3
# Completed: 66 steps2
# Completed: 67 stepsEmpate
# Completed: 68 stepsEmpate
# Completed: 69 steps2
# Completed: 70 steps1
# Completed: 71 steps3
# Completed: 72 stepsEmpate
# Completed: 73 stepsEmpate
# Completed: 74 steps2
# Completed: 75 stepsEmpate
# Completed: 76 stepsEmpate
# Completed: 77 stepsEmpate
# Completed: 78 steps2
# Completed: 79 stepsEmpate
# Completed: 80 stepsEmpate
# Completed: 81 stepsEmpate
# Completed: 82 stepsEmpate
# Completed: 83 steps3
# Completed: 84 steps2
# Completed: 85 stepsEmpate
# Completed: 86 steps3
# Completed: 87 stepsEmpate
# Completed: 88 stepsEmpate
# Completed: 89 steps2
# Completed: 90 stepsEmpate
# Completed: 91 stepsEmpate
# Completed: 92 steps2
# Completed: 93 stepsEmpate
# Completed: 94 steps3
# Completed: 95 stepsEmpate
# Completed: 96 steps3
# Completed: 97 stepsEmpate
# Completed: 98 steps2
# Completed: 99 stepsEmpate
# Completed: 100 stepsEmpate
# Completed: 101 stepsEmpate
# Completed: 102 stepsEmpate
# Completed: 103 steps3
# Completed: 104 steps2
# Completed: 105 steps1
# Completed: 106 stepsEmpate
# Completed: 107 stepsEmpate
# Completed: 108 steps3
# Completed: 109 stepsEmpate
# Completed: 110 steps3
# Completed: 111 stepsEmpate
# Completed: 112 steps2
# Completed: 113 steps1
# Completed: 114 steps3
# Completed: 115 steps2
# Completed: 116 stepsEmpate
# Completed: 117 steps3
# Completed: 118 stepsEmpate
# Completed: 119 steps2
# Completed: 120 steps1
# Completed: 121 steps3
# Completed: 122 steps2
# Completed: 123 stepsEmpate
# Completed: 124 steps2
# Completed: 125 stepsEmpate
# Completed: 126 stepsEmpate
# Completed: 127 steps2
# Completed: 128 stepsEmpate
# Completed: 129 stepsEmpate
# Completed: 130 steps3
# Completed: 131 steps2
# Completed: 132 steps1
# Completed: 133 stepsEmpate
# Completed: 134 stepsEmpate
# Completed: 135 stepsEmpate
# Completed: 136 stepsEmpate
# Completed: 137 stepsEmpate
# Completed: 138 steps2
# Completed: 139 steps1
# Completed: 140 steps3
# Completed: 141 stepsEmpate
# Completed: 142 steps2
# Completed: 143 stepsEmpate
# Completed: 144 steps3
# Completed: 145 steps2
# Completed: 146 stepsEmpate
# Completed: 147 stepsEmpate
# Completed: 148 steps2
# Completed: 149 stepsEmpate
# Completed: 150 stepsEmpate
# Completed: 151 stepsEmpate
# Completed: 152 stepsEmpate
# Completed: 153 steps3
# Completed: 154 steps2
# Completed: 155 stepsEmpate
# Completed: 156 stepsEmpate
# Completed: 157 stepsEmpate
# Completed: 158 steps2
# Completed: 159 steps1
# Completed: 160 stepsEmpate
# Completed: 161 stepsEmpate
# Completed: 162 stepsEmpate
# Completed: 163 stepsEmpate
# Completed: 164 steps2
# Completed: 165 steps1
# Completed: 166 steps3
# Completed: 167 stepsEmpate
# Completed: 168 steps2
# Completed: 169 steps1
# Completed: 170 stepsEmpate
# Completed: 171 stepsEmpate
# Completed: 172 steps3
# Completed: 173 steps2
# Completed: 174 steps1
# Completed: 175 steps3
# Completed: 176 steps2
# Completed: 177 stepsEmpate
# Completed: 178 steps2
# Completed: 179 stepsEmpate
# Completed: 180 stepsEmpate
# Completed: 181 steps3
# Completed: 182 steps2
# Completed: 183 steps1
# Completed: 184 stepsEmpate
# Completed: 185 steps3
# Completed: 186 stepsEmpate
# Completed: 187 stepsEmpate
# Completed: 188 stepsEmpate
# Completed: 189 steps3
# Completed: 190 steps2
# Completed: 191 steps1
# Completed: 192 steps3
# Completed: 193 stepsEmpate
# Completed: 194 steps3
# Completed: 195 stepsEmpate
# Completed: 196 steps2
# Completed: 197 stepsEmpate
# Completed: 198 steps2
# Completed: 199 steps1
# Completed: 200 stepsEmpate
# Completed: 201 steps2
# Completed: 202 stepsEmpate
# Completed: 203 steps3
# Completed: 204 steps2
# Completed: 205 steps1
# Completed: 206 steps3
# Completed: 207 stepsEmpate
# Completed: 208 steps2
# Completed: 209 stepsEmpate
# Completed: 210 stepsEmpate
# Completed: 211 steps2
# Completed: 212 steps1
# Completed: 213 steps3
# Completed: 214 stepsEmpate
# Completed: 215 stepsEmpate
# Completed: 216 stepsEmpate
# Completed: 217 stepsEmpate
# Completed: 218 steps2
# Completed: 219 stepsEmpate
# Completed: 220 steps3
# Completed: 221 steps2
# Completed: 222 steps1
# Completed: 223 stepsEmpate
# Completed: 224 stepsEmpate
# Completed: 225 stepsEmpate
# Completed: 226 stepsEmpate
# Completed: 227 stepsEmpate
# Completed: 228 steps3
# Completed: 229 stepsEmpate
# Completed: 230 steps3
# Completed: 231 steps2
# Completed: 232 steps1
# Completed: 233 steps3
# Completed: 234 stepsEmpate
# Completed: 235 stepsEmpate
# Completed: 236 steps3
# Completed: 237 stepsEmpate
# Completed: 238 steps2
# Completed: 239 stepsEmpate
# Completed: 240 stepsEmpate
# Completed: 241 steps3
# Completed: 242 steps2
# Completed: 243 steps1
# Completed: 244 stepsEmpate
# Completed: 245 stepsEmpate
# Completed: 246 steps3
# Completed: 247 stepsEmpate
# Completed: 248 steps3
# Completed: 249 steps2
# Completed: 250 stepsEmpate
# Completed: 251 stepsEmpate
# Completed: 252 stepsEmpate
# Completed: 253 stepsEmpate
# Completed: 254 steps3
# Completed: 255 steps2
# Completed: 256 steps1
# Completed: 257 steps3
# Completed: 258 stepsEmpate
# Completed: 259 stepsEmpate
# Completed: 260 steps3
# Completed: 261 steps2
# Completed: 262 stepsEmpate
# Completed: 263 stepsEmpate
# Completed: 264 stepsEmpate
# Completed: 265 steps2
# Completed: 266 stepsEmpate
# Completed: 267 steps2
# Completed: 268 stepsEmpate
# Completed: 269 steps3
# Completed: 270 steps2
# Completed: 271 steps1
# Completed: 272 stepsEmpate
# Completed: 273 steps2
# Completed: 274 stepsEmpate
# Completed: 275 steps3
# Completed: 276 steps2
# Completed: 277 stepsEmpate
# Completed: 278 steps2
# Completed: 279 steps1
# Completed: 280 stepsEmpate
# Completed: 281 steps2
# Completed: 282 stepsEmpate
# Completed: 283 stepsEmpate
# Completed: 284 stepsEmpate
# Completed: 285 stepsEmpate
# Completed: 286 steps3
# Completed: 287 stepsEmpate
# Completed: 288 steps3
# Completed: 289 stepsEmpate
# Completed: 290 stepsEmpate
# Completed: 291 stepsEmpate
# Completed: 292 steps3
# Completed: 293 steps2
# Completed: 294 steps1
# Completed: 295 steps3
# Completed: 296 stepsEmpate
# Completed: 297 steps2
# Completed: 298 stepsEmpate
# Completed: 299 stepsEmpate
# Completed: 300 stepsEmpate
# Completed: 301 stepsEmpate
# Completed: 302 steps3
# Completed: 303 steps2
# Completed: 304 stepsEmpate
# Completed: 305 steps3
# Completed: 306 steps2
# Completed: 307 stepsEmpate
# Completed: 308 stepsEmpate
# Completed: 309 stepsEmpate
# Completed: 310 steps2
# Completed: 311 stepsEmpate
# Completed: 312 stepsEmpate
# Completed: 313 steps2
# Completed: 314 steps1
# Completed: 315 stepsEmpate
# Completed: 316 steps3
# Completed: 317 stepsEmpate
# Completed: 318 steps2
# Completed: 319 stepsEmpate
# Completed: 320 steps3
# Completed: 321 steps2
# Completed: 322 stepsEmpate
# Completed: 323 stepsEmpate
# Completed: 324 steps2
# Completed: 325 steps1
# Completed: 326 stepsEmpate
# Completed: 327 steps3
# Completed: 328 steps2
# Completed: 329 steps1
# Completed: 330 stepsEmpate
# Completed: 331 steps2
# Completed: 332 stepsEmpate
# Completed: 333 stepsEmpate
# Completed: 334 steps3
# Completed: 335 steps2
# Completed: 336 stepsEmpate
# Completed: 337 stepsEmpate
# Completed: 338 stepsEmpate
# Completed: 339 stepsEmpate
# Completed: 340 stepsEmpate
# Completed: 341 steps3
# Completed: 342 stepsEmpate
# Completed: 343 stepsEmpate
# Completed: 344 steps2
# Completed: 345 stepsEmpate
# Completed: 346 steps2
# Completed: 347 stepsEmpate
# Completed: 348 steps3
# Completed: 349 steps2
# Completed: 350 stepsEmpate
# Completed: 351 steps2
# Completed: 352 steps1
# Completed: 353 stepsEmpate
# Completed: 354 steps2
# Completed: 355 steps1
# Completed: 356 stepsEmpate
# Completed: 357 steps2
# Completed: 358 stepsEmpate
# Completed: 359 steps3
# Completed: 360 stepsEmpate
# Completed: 361 stepsEmpate
# Completed: 362 stepsEmpate
# Completed: 363 steps2
# Completed: 364 stepsEmpate
# Completed: 365 steps3
# Completed: 366 stepsEmpate
# Completed: 367 stepsEmpate
# Completed: 368 steps3
# Completed: 369 steps2
# Completed: 370 stepsEmpate
# Completed: 371 stepsEmpate
# Completed: 372 stepsEmpate
# Completed: 373 stepsEmpate
# Completed: 374 steps3
# Completed: 375 stepsEmpate
# Completed: 376 steps3
# Completed: 377 stepsEmpate
# Completed: 378 steps3
# Completed: 379 stepsEmpate
# Completed: 380 steps2
# Completed: 381 steps1
# Completed: 382 stepsEmpate
# Completed: 383 stepsEmpate
# Completed: 384 steps3
# Completed: 385 steps2
# Completed: 386 stepsEmpate
# Completed: 387 stepsEmpate
# Completed: 388 stepsEmpate
# Completed: 389 stepsEmpate
# Completed: 390 stepsEmpate
# Completed: 391 stepsEmpate
# Completed: 392 stepsEmpate
# Completed: 393 steps2
# Completed: 394 steps1
# Completed: 395 stepsEmpate
# Completed: 396 stepsEmpate
# Completed: 397 stepsEmpate
# Completed: 398 stepsEmpate
# Completed: 399 stepsEmpate
# Completed: 400 stepsEmpate
# Completed: 401 steps3
# Completed: 402 stepsEmpate
# Completed: 403 stepsEmpate
# Completed: 404 steps3
# Completed: 405 steps2
# Completed: 406 steps1
# Completed: 407 stepsEmpate
# Completed: 408 steps3
# Completed: 409 steps2
# Completed: 410 steps1
# Completed: 411 stepsEmpate
# Completed: 412 steps2
# Completed: 413 stepsEmpate
# Completed: 414 stepsEmpate
# Completed: 415 steps2
# Completed: 416 stepsEmpate
# Completed: 417 steps2
# Completed: 418 stepsEmpate
# Completed: 419 stepsEmpate
# Completed: 420 stepsEmpate
# Completed: 421 steps2
# Completed: 422 stepsEmpate
# Completed: 423 stepsEmpate
# Completed: 424 stepsEmpate
# Completed: 425 stepsEmpate
# Completed: 426 stepsEmpate
# Completed: 427 steps3
# Completed: 428 steps2
# Completed: 429 steps1
# Completed: 430 steps3
# Completed: 431 stepsEmpate
# Completed: 432 stepsEmpate
# Completed: 433 stepsEmpate
# Completed: 434 stepsEmpate
# Completed: 435 steps3
# Completed: 436 steps2
# Completed: 437 stepsEmpate
# Completed: 438 steps2
# Completed: 439 steps1
# Completed: 440 stepsEmpate
# Completed: 441 stepsEmpate
# Completed: 442 steps3
# Completed: 443 stepsEmpate
# Completed: 444 stepsEmpate
# Completed: 445 steps2
# Completed: 446 stepsEmpate
# Completed: 447 stepsEmpate
# Completed: 448 stepsEmpate
# Completed: 449 stepsEmpate
# Completed: 450 steps3
# Completed: 451 steps2
# Completed: 452 stepsEmpate
# Completed: 453 steps3
# Completed: 454 stepsEmpate
# Completed: 455 steps2
# Completed: 456 stepsEmpate
# Completed: 457 steps2
# Completed: 458 steps1
# Completed: 459 stepsEmpate
# Completed: 460 stepsEmpate
# Completed: 461 steps2
# Completed: 462 stepsEmpate
# Completed: 463 stepsEmpate
# Completed: 464 steps3
# Completed: 465 stepsEmpate
# Completed: 466 steps2
# Completed: 467 stepsEmpate
# Completed: 468 steps3
# Completed: 469 steps2
# Completed: 470 stepsEmpate
# Completed: 471 stepsEmpate
# Completed: 472 stepsEmpate
# Completed: 473 steps3
# Completed: 474 stepsEmpate
# Completed: 475 steps2
# Completed: 476 steps1
# Completed: 477 steps3
# Completed: 478 steps2
# Completed: 479 steps1
# Completed: 480 stepsEmpate
# Completed: 481 stepsEmpate
# Completed: 482 stepsEmpate
# Completed: 483 stepsEmpate
# Completed: 484 steps3
# Completed: 485 stepsEmpate
# Completed: 486 steps3
# Completed: 487 steps2
# Completed: 488 stepsEmpate
# Completed: 489 steps3
# Completed: 490 steps2
# Completed: 491 stepsEmpate
# Completed: 492 steps2
# Completed: 493 stepsEmpate
# Completed: 494 stepsEmpate
# Completed: 495 stepsEmpate
# Completed: 496 steps3
# Completed: 497 stepsEmpate
# Completed: 498 stepsEmpate
# Completed: 499 steps3
# Completed: 500 steps2
# Completed: 501 steps1
# Completed: 502 stepsEmpate
# Completed: 503 steps3
# Completed: 504 steps2
# Completed: 505 steps1
# Completed: 506 steps3
# Completed: 507 steps2
# Completed: 508 stepsEmpate
# Completed: 509 stepsEmpate
# Completed: 510 stepsEmpate
# Completed: 511 steps3
# Completed: 512 stepsEmpate
# Completed: 513 stepsEmpate
# Completed: 514 stepsEmpate
# Completed: 515 stepsEmpate
# Completed: 516 stepsEmpate
# Completed: 517 stepsEmpate
# Completed: 518 steps2
# Completed: 519 steps1
# Completed: 520 stepsEmpate
# Completed: 521 steps3
# Completed: 522 stepsEmpate
# Completed: 523 stepsEmpate
# Completed: 524 steps2
# Completed: 525 steps1
# Completed: 526 steps3
# Completed: 527 steps2
# Completed: 528 stepsEmpate
# Completed: 529 steps3
# Completed: 530 stepsEmpate
# Completed: 531 stepsEmpate
# Completed: 532 stepsEmpate
# Completed: 533 steps3
# Completed: 534 steps2
# Completed: 535 stepsEmpate
# Completed: 536 steps2
# Completed: 537 stepsEmpate
# Completed: 538 stepsEmpate
# Completed: 539 stepsEmpate
# Completed: 540 steps2
# Completed: 541 steps1
# Completed: 542 steps3
# Completed: 543 steps2
# Completed: 544 stepsEmpate
# Completed: 545 steps2
# Completed: 546 steps1
# Completed: 547 stepsEmpate
# Completed: 548 stepsEmpate
# Completed: 549 stepsEmpate
# Completed: 550 steps2
# Completed: 551 stepsEmpate
# Completed: 552 steps3
# Completed: 553 stepsEmpate
# Completed: 554 stepsEmpate
# Completed: 555 steps3
# Completed: 556 stepsEmpate
# Completed: 557 steps3
# Completed: 558 steps2
# Completed: 559 stepsEmpate
# Completed: 560 steps2
# Completed: 561 steps1
# Completed: 562 stepsEmpate
# Completed: 563 stepsEmpate
# Completed: 564 stepsEmpate
# Completed: 565 stepsEmpate
# Completed: 566 steps2
# Completed: 567 steps1
# Completed: 568 stepsEmpate
# Completed: 569 steps2
# Completed: 570 stepsEmpate
# Completed: 571 steps3
# Completed: 572 steps2
# Completed: 573 steps1
# Completed: 574 steps3
# Completed: 575 steps2
# Completed: 576 stepsEmpate
# Completed: 577 steps2
# Completed: 578 steps1
# Completed: 579 stepsEmpate
# Completed: 580 stepsEmpate
# Completed: 581 stepsEmpate
# Completed: 582 stepsEmpate
# Completed: 583 steps3
# Completed: 584 stepsEmpate
# Completed: 585 steps3
# Completed: 586 steps2
# Completed: 587 stepsEmpate
# Completed: 588 stepsEmpate
# Completed: 589 stepsEmpate
# Completed: 590 stepsEmpate
# Completed: 591 stepsEmpate
# Completed: 592 stepsEmpate
# Completed: 593 steps3
# Completed: 594 steps2
# Completed: 595 stepsEmpate
# Completed: 596 stepsEmpate
# Completed: 597 steps3
# Completed: 598 steps2
# Completed: 599 steps1
# Completed: 600 steps3
# Completed: 601 stepsEmpate
# Completed: 602 steps2
# Completed: 603 stepsEmpate
# Completed: 604 steps3
# Completed: 605 stepsEmpate
# Completed: 606 stepsEmpate
# Completed: 607 steps2
# Completed: 608 steps1
# Completed: 609 steps3
# Completed: 610 steps2
# Completed: 611 stepsEmpate
# Completed: 612 steps3
# Completed: 613 steps2
# Completed: 614 stepsEmpate
# Completed: 615 stepsEmpate
# Completed: 616 stepsEmpate
# Completed: 617 steps2
# Completed: 618 steps1
# Completed: 619 stepsEmpate
# Completed: 620 stepsEmpate
# Completed: 621 stepsEmpate
# Completed: 622 stepsEmpate
# Completed: 623 stepsEmpate
# Completed: 624 steps3
# Completed: 625 stepsEmpate
# Completed: 626 stepsEmpate
# Completed: 627 stepsEmpate
# Completed: 628 stepsEmpate
# Completed: 629 stepsEmpate
# Completed: 630 steps2
# Completed: 631 stepsEmpate
# Completed: 632 steps2
# Completed: 633 steps1
# Completed: 634 steps3
# Completed: 635 steps2
# Completed: 636 stepsEmpate
# Completed: 637 stepsEmpate
# Completed: 638 stepsEmpate
# Completed: 639 stepsEmpate
# Completed: 640 stepsEmpate
# Completed: 641 steps3
# Completed: 642 stepsEmpate
# Completed: 643 steps3
# Completed: 644 steps2
# Completed: 645 stepsEmpate
# Completed: 646 steps3
# Completed: 647 stepsEmpate
# Completed: 648 stepsEmpate
# Completed: 649 steps3
# Completed: 650 stepsEmpate
# Completed: 651 steps3
# Completed: 652 stepsEmpate
# Completed: 653 stepsEmpate
# Completed: 654 stepsEmpate
# Completed: 655 stepsEmpate
# Completed: 656 steps3
# Completed: 657 steps2
# Completed: 658 stepsEmpate
# Completed: 659 stepsEmpate
# Completed: 660 steps2
# Completed: 661 steps1
# Completed: 662 steps3
# Completed: 663 stepsEmpate
# Completed: 664 stepsEmpate
# Completed: 665 steps3
# Completed: 666 steps2
# Completed: 667 stepsEmpate
# Completed: 668 stepsEmpate
# Completed: 669 steps2
# Completed: 670 steps1
# Completed: 671 steps3
# Completed: 672 stepsEmpate
# Completed: 673 stepsEmpate
# Completed: 674 steps3
# Completed: 675 steps2
# Completed: 676 steps1
# Completed: 677 stepsEmpate
# Completed: 678 steps3
# Completed: 679 stepsEmpate
# Completed: 680 stepsEmpate
# Completed: 681 stepsEmpate
# Completed: 682 steps3
# Completed: 683 stepsEmpate
# Completed: 684 stepsEmpate
# Completed: 685 stepsEmpate
# Completed: 686 stepsEmpate
# Completed: 687 steps3
# Completed: 688 stepsEmpate
# Completed: 689 stepsEmpate
# Completed: 690 stepsEmpate
# Completed: 691 steps2
# Completed: 692 steps1
# Completed: 693 stepsEmpate
# Completed: 694 steps3
# Completed: 695 steps2
# Completed: 696 stepsEmpate
# Completed: 697 steps2
# Completed: 698 stepsEmpate
# Completed: 699 stepsEmpate
# Completed: 700 steps2
# Completed: 701 steps1
# Completed: 702 stepsEmpate
# Completed: 703 stepsEmpate
# Completed: 704 stepsEmpate
# Completed: 705 stepsEmpate
# Completed: 706 stepsEmpate
# Completed: 707 stepsEmpate
# Completed: 708 steps3
# Completed: 709 steps2
# Completed: 710 steps1
# Completed: 711 stepsEmpate
# Completed: 712 stepsEmpate
# Completed: 713 stepsEmpate
# Completed: 714 steps2
# Completed: 715 steps1
# Completed: 716 steps3
# Completed: 717 stepsEmpate
# Completed: 718 steps2
# Completed: 719 stepsEmpate
# Completed: 720 steps3
# Completed: 721 stepsEmpate
# Completed: 722 steps2
# Completed: 723 steps1
# Completed: 724 stepsEmpate
# Completed: 725 steps3
# Completed: 726 stepsEmpate
# Completed: 727 steps3
# Completed: 728 steps2
# Completed: 729 stepsEmpate
# Completed: 730 steps2
# Completed: 731 stepsEmpate
# Completed: 732 stepsEmpate
# Completed: 733 stepsEmpate
# Completed: 734 steps3
# Completed: 735 stepsEmpate
# Completed: 736 steps3
# Completed: 737 stepsEmpate
# Completed: 738 steps2
# Completed: 739 steps1
# Completed: 740 stepsEmpate
# Completed: 741 stepsEmpate
# Completed: 742 steps3
# Completed: 743 steps2
# Completed: 744 steps1
# Completed: 745 steps3
# Completed: 746 steps2
# Completed: 747 steps1
# Completed: 748 stepsEmpate
# Completed: 749 steps2
# Completed: 750 steps1
# Completed: 751 stepsEmpate
# Completed: 752 steps2
# Completed: 753 steps1
# Completed: 754 steps3
# Completed: 755 steps2
# Completed: 756 steps1
# Completed: 757 stepsEmpate
# Completed: 758 steps2
# Completed: 759 stepsEmpate
# Completed: 760 stepsEmpate
# Completed: 761 stepsEmpate
# Completed: 762 steps3
# Completed: 763 steps2
# Completed: 764 stepsEmpate
# Completed: 765 steps3
# Completed: 766 stepsEmpate
# Completed: 767 steps2
# Completed: 768 steps1
# Completed: 769 stepsEmpate
# Completed: 770 stepsEmpate
# Completed: 771 steps3
# Completed: 772 steps2
# Completed: 773 steps1
# Completed: 774 steps3
# Completed: 775 stepsEmpate
# Completed: 776 steps2
# Completed: 777 stepsEmpate
# Completed: 778 steps2
# Completed: 779 steps1
# Completed: 780 stepsEmpate
# Completed: 781 stepsEmpate
# Completed: 782 steps2
# Completed: 783 steps1
# Completed: 784 steps3
# Completed: 785 stepsEmpate
# Completed: 786 steps2
# Completed: 787 steps1
# Completed: 788 steps3
# Completed: 789 steps2
# Completed: 790 steps1
# Completed: 791 steps3
# Completed: 792 stepsEmpate
# Completed: 793 stepsEmpate
# Completed: 794 steps2
# Completed: 795 steps1
# Completed: 796 steps3
# Completed: 797 stepsEmpate
# Completed: 798 stepsEmpate
# Completed: 799 stepsEmpate
# Completed: 800 stepsEmpate
# Completed: 801 steps2
# Completed: 802 steps1
# Completed: 803 steps3
# Completed: 804 stepsEmpate
# Completed: 805 steps2
# Completed: 806 stepsEmpate
# Completed: 807 stepsEmpate
# Completed: 808 steps3
# Completed: 809 steps2
# Completed: 810 stepsEmpate
# Completed: 811 stepsEmpate
# Completed: 812 stepsEmpate
# Completed: 813 steps3
# Completed: 814 steps2
# Completed: 815 stepsEmpate
# Completed: 816 steps2
# Completed: 817 steps1
# Completed: 818 stepsEmpate
# Completed: 819 steps2
# Completed: 820 steps1
# Completed: 821 stepsEmpate
# Completed: 822 stepsEmpate
# Completed: 823 steps3
# Completed: 824 steps2
# Completed: 825 stepsEmpate
# Completed: 826 stepsEmpate
# Completed: 827 steps2
# Completed: 828 stepsEmpate
# Completed: 829 stepsEmpate
# Completed: 830 stepsEmpate
# Completed: 831 steps2
# Completed: 832 stepsEmpate
# Completed: 833 stepsEmpate
# Completed: 834 stepsEmpate
# Completed: 835 steps3
# Completed: 836 steps2
# Completed: 837 steps1
# Completed: 838 stepsEmpate
# Completed: 839 steps3
# Completed: 840 stepsEmpate
# Completed: 841 stepsEmpate
# Completed: 842 stepsEmpate
# Completed: 843 steps3
# Completed: 844 steps2
# Completed: 845 stepsEmpate
# Completed: 846 stepsEmpate
# Completed: 847 steps3
# Completed: 848 steps2
# Completed: 849 stepsEmpate
# Completed: 850 stepsEmpate
# Completed: 851 stepsEmpate
# Completed: 852 stepsEmpate
# Completed: 853 stepsEmpate
# Completed: 854 stepsEmpate
# Completed: 855 stepsEmpate
# Completed: 856 stepsEmpate
# Completed: 857 stepsEmpate
# Completed: 858 steps3
# Completed: 859 stepsEmpate
# Completed: 860 steps2
# Completed: 861 steps1
# Completed: 862 stepsEmpate
# Completed: 863 stepsEmpate
# Completed: 864 steps2
# Completed: 865 steps1
# Completed: 866 steps3
# Completed: 867 stepsEmpate
# Completed: 868 stepsEmpate
# Completed: 869 steps3
# Completed: 870 stepsEmpate
# Completed: 871 stepsEmpate
# Completed: 872 stepsEmpate
# Completed: 873 steps2
# Completed: 874 stepsEmpate
# Completed: 875 stepsEmpate
# Completed: 876 stepsEmpate
# Completed: 877 steps3
# Completed: 878 steps2
# Completed: 879 steps1
# Completed: 880 stepsEmpate
# Completed: 881 steps2
# Completed: 882 steps1
# Completed: 883 steps3
# Completed: 884 steps2
# Completed: 885 steps1
# Completed: 886 steps3
# Completed: 887 stepsEmpate
# Completed: 888 stepsEmpate
# Completed: 889 steps2
# Completed: 890 steps1
# Completed: 891 steps3
# Completed: 892 stepsEmpate
# Completed: 893 steps3
# Completed: 894 steps2
# Completed: 895 stepsEmpate
# Completed: 896 steps3
# Completed: 897 stepsEmpate
# Completed: 898 steps3
# Completed: 899 stepsEmpate
# Completed: 900 stepsEmpate
# Completed: 901 steps3
# Completed: 902 stepsEmpate
# Completed: 903 steps3
# Completed: 904 steps2
# Completed: 905 steps1
# Completed: 906 stepsEmpate
# Completed: 907 stepsEmpate
# Completed: 908 stepsEmpate
# Completed: 909 steps2
# Completed: 910 steps1
# Completed: 911 steps3
# Completed: 912 steps2
# Completed: 913 stepsEmpate
# Completed: 914 steps2
# Completed: 915 stepsEmpate
# Completed: 916 steps2
# Completed: 917 stepsEmpate
# Completed: 918 steps3
# Completed: 919 steps2
# Completed: 920 steps1
# Completed: 921 steps3
# Completed: 922 stepsEmpate
# Completed: 923 stepsEmpate
# Completed: 924 steps3
# Completed: 925 steps2
# Completed: 926 steps1
# Completed: 927 stepsEmpate
# Completed: 928 stepsEmpate
# Completed: 929 steps3
# Completed: 930 stepsEmpate
# Completed: 931 steps2
# Completed: 932 steps1
# Completed: 933 steps3
# Completed: 934 steps2
# Completed: 935 stepsEmpate
# Completed: 936 stepsEmpate
# Completed: 937 steps3
# Completed: 938 stepsEmpate
# Completed: 939 stepsEmpate
# Completed: 940 steps2
# Completed: 941 stepsEmpate
# Completed: 942 steps3
# Completed: 943 steps2
# Completed: 944 steps1
# Completed: 945 stepsEmpate
# Completed: 946 steps3
# Completed: 947 steps2
# Completed: 948 stepsEmpate
# Completed: 949 stepsEmpate
# Completed: 950 stepsEmpate
# Completed: 951 stepsEmpate
# Completed: 952 stepsEmpate
# Completed: 953 steps2
# Completed: 954 stepsEmpate
# Completed: 955 stepsEmpate
# Completed: 956 steps3
# Completed: 957 steps2
# Completed: 958 steps1
# Completed: 959 stepsEmpate
# Completed: 960 stepsEmpate
# Completed: 961 steps2
# Completed: 962 stepsEmpate
# Completed: 963 stepsEmpate
# Completed: 964 steps2
# Completed: 965 stepsEmpate
# Completed: 966 stepsEmpate
# Completed: 967 steps3
# Completed: 968 steps2
# Completed: 969 stepsEmpate
# Completed: 970 stepsEmpate
# Completed: 971 steps2
# Completed: 972 stepsEmpate
# Completed: 973 stepsEmpate
# Completed: 974 steps2
# Completed: 975 stepsEmpate
# Completed: 976 stepsEmpate
# Completed: 977 steps2
# Completed: 978 steps1
# Completed: 979 stepsEmpate
# Completed: 980 steps2
# Completed: 981 stepsEmpate
# Completed: 982 steps3
# Completed: 983 stepsEmpate
# Completed: 984 steps2
# Completed: 985 stepsEmpate
# Completed: 986 steps2
# Completed: 987 steps1
# Completed: 988 steps3
# Completed: 989 steps2
# Completed: 990 steps1
# Completed: 991 stepsEmpate
# Completed: 992 steps3
# Completed: 993 steps2
# Completed: 994 steps1
# Completed: 995 stepsEmpate
# Completed: 996 steps2
# Completed: 997 stepsEmpate
# Completed: 998 stepsEmpate
# Completed: 999 stepsEmpate
# Victorias jugador 1: 99
# Victorias jugador 2: 221
# Victorias jugador 3: 174
# Victorias jugador 4: 0
# Empates : 506
# Ganó jugador 2: 221 veces
# Completed: 1000 steps
# Run time: 0:00:00.107713
# Simulation finished

# %%
results.values()
results.info
# Out:
# {'model_type': 'DisparejoModel',
#  'time_stamp': '2022-11-14 13:10:37',
#  'agentpy_version': '0.1.5',
#  'python_version': '3.11.',
#  'experiment': False,
#  'completed': True,
#  'created_objects': 4,
#  'completed_steps': 1000,
#  'run_time': '0:00:00.107713'}

# %%
results.variables.DisparejoModel.head()
# Out:
#         Partida  Winner
# t
# 1  [1, 0, 1, 0]        5
# 2  [0, 0, 1, 1]        5
# 3  [0, 0, 1, 0]        3
# 4  [1, 0, 1, 1]        2
# 5  [0, 0, 0, 0]        5

# %% [markdown]
# En la siguiente gráfica, se puede visualizar el número de victorias en los 1000 juegos. Los números del 1 al 4 representan a cada jugador, y el número representa los empates que sucedieron.

# %%
data = results.variables.DisparejoModel
ax = data.plot()
